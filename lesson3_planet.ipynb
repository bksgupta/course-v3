# %% [markdown]
# <a href="https://colab.research.google.com/github/bksgupta/course-v3/blob/master/lesson3_planet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Multi-label prediction with Planet Amazon dataset

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from fastai.vision import *

# %% [markdown]
# ## Getting the data

# %% [markdown]
# The planet dataset isn't available on the [fastai dataset page](https://course.fast.ai/datasets) due to copyright restrictions. You can download it from Kaggle however. Let's see how to do this by using the [Kaggle API](https://github.com/Kaggle/kaggle-api) as it's going to be pretty useful to you if you want to join a competition or use other Kaggle datasets later on.
#
# First, install the Kaggle API by uncommenting the following line and executing it, or by executing it in your terminal (depending on your platform you may need to modify this slightly to either add `source activate fastai` or similar, or prefix `pip` with a path. Have a look at how `conda install` is called for your platform in the appropriate *Returning to work* section of https://course.fast.ai/. (Depending on your environment, you may also need to append "--user" to the command.)

# %%
! {sys.executable} -m pip install kaggle --upgrade
# Out:
# Requirement already up-to-date: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied, skipping upgrade: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied, skipping upgrade: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied, skipping upgrade: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied, skipping upgrade: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.9)

# %% [markdown]
# Then you need to upload your credentials from Kaggle on your instance. Login to kaggle and click on your profile picture on the top left corner, then 'My account'. Scroll down until you find a button named 'Create New API Token' and click on it. This will trigger the download of a file named 'kaggle.json'.
#
# Upload this file to the directory this notebook is running in, by clicking "Upload" on your main Jupyter page, then uncomment and execute the next two commands (or run them in a terminal). For Windows, uncomment the last two commands.

# %%
! mkdir -p ~/.kaggle/
! mv kaggle.json ~/.kaggle/

# For Windows, uncomment these two commands
# ! mkdir %userprofile%\.kaggle
# ! move kaggle.json %userprofile%\.kaggle

# %% [markdown]
# You're all set to download the data from [planet competition](https://www.kaggle.com/c/planet-understanding-the-amazon-from-space). You **first need to go to its main page and accept its rules**, and run the two cells below (uncomment the shell commands to download and unzip the data). If you get a `403 forbidden` error it means you haven't accepted the competition rules yet (you have to go to the competition page, click on *Rules* tab, and then scroll to the bottom to find the *accept* button).

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
Config.data_path()
# Out:
# PosixPath('/root/.fastai/data')

# %%
path = Config.data_path()/'planet'
path.mkdir(parents=True, exist_ok=True)
path
# Out:
# PosixPath('/root/.fastai/data/planet')

# %%
! cp "/content/drive/My Drive/data/kaggle/train-jpg.tar.7z" {path}

# %%
! cp "/content/drive/My Drive/data/kaggle/train_v2.csv.zip" {path}

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/planet/train-jpg.tar.7z'),
#  PosixPath('/root/.fastai/data/planet/train_v2.csv.zip'),
#  PosixPath('/root/.fastai/data/planet/train-jpg'),
#  PosixPath('/root/.fastai/data/planet/train_v2.csv')]

# %%
# ! kaggle competitions download -c planet-understanding-the-amazon-from-space -f train-jpg.tar.7z -p {path}  
# ! kaggle competitions download -c planet-understanding-the-amazon-from-space -f train_v2.csv -p {path}  
! unzip -q -n {path}/train_v2.csv.zip -d {path}

# %% [markdown]
# To extract the content of this file, we'll need 7zip, so uncomment the following line if you need to install it (or run `sudo apt install p7zip-full` in your terminal).

# %%
# ! conda install --yes --prefix {sys.prefix} -c haasad eidl7zip
# Out:
# /bin/bash: conda: command not found

# %% [markdown]
# And now we can unpack the data (uncomment to run - this might take a few minutes to complete).

# %%
path.as_posix()
# Out:
# '/root/.fastai/data/planet'

# %%
! 7za -bd -y -so x {path}/train-jpg.tar.7z | tar xf - -C {path.as_posix()}

# %% [markdown]
# ## Multiclassification

# %% [markdown]
# Contrary to the pets dataset studied in last lesson, here each picture can have multiple labels. If we take a look at the csv file containing the labels (in 'train_v2.csv' here) we see that each 'image_name' is associated to several tags separated by spaces.

# %%
a = path/'train-jpg'
a.ls()
# Out:
# [PosixPath('/root/.fastai/data/planet/train-jpg/train_26155.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18585.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32382.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30922.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7607.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11953.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18048.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32999.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37966.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36384.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39220.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20063.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29542.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34493.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33281.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13269.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38369.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39478.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16013.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17522.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10396.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20026.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3525.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27767.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11488.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17168.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25358.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16674.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12115.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19939.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37559.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30241.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32782.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9286.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30942.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34173.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31984.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32289.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12798.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36277.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38058.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29510.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19666.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29229.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11900.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5685.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27684.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2254.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22870.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23040.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8442.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20833.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27260.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23906.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36350.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1058.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15184.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6156.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1456.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37805.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8794.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30725.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23700.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17731.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6326.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39337.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36588.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9108.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10711.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29769.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32722.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24134.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30327.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30514.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17227.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31597.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12393.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27641.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24298.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12667.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_676.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39445.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_936.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28767.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2960.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26296.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12908.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29963.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18379.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25607.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8878.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36703.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20796.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11066.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37506.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25006.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39643.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7089.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21772.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7423.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1187.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11429.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30199.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13928.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9842.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2754.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15201.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36288.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1879.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11210.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18696.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11818.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15355.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29968.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2727.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4196.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17926.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24528.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2915.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20909.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12003.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4747.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5778.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11455.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2111.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2482.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31089.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37293.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33679.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31784.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5841.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4155.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26889.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24930.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20145.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17249.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9940.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22253.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19366.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16354.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27344.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8546.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36301.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22213.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36072.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31423.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27262.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20703.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32183.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7406.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16418.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28081.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22711.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10013.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26701.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10019.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2545.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28347.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9726.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30394.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22406.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33346.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9199.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38479.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25807.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28561.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25791.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19279.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13323.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_821.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35473.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17653.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34126.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37305.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35663.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32742.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17343.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30087.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8204.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10676.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38340.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16479.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15122.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28030.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8776.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4933.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39033.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21058.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14982.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10265.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2949.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39573.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35641.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34010.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19677.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24639.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16655.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_384.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24759.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8123.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8451.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4015.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31234.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7861.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29462.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28349.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31492.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35464.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1157.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20419.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11392.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4082.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13975.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33306.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27713.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35941.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17509.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20189.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6147.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22248.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14874.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21472.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_40260.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24192.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_40155.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23364.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10590.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_311.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9251.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27872.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12569.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8692.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31480.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3217.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29241.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24706.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21885.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4414.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20201.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20995.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2997.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23325.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34695.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23220.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33009.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5749.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34444.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33936.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33178.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3031.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3518.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9222.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17110.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25138.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33240.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29786.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15624.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5203.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8276.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1347.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39699.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6033.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17065.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5293.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19298.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17979.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22658.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14945.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22717.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33431.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27214.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5485.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32735.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10177.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34447.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20503.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29257.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24183.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28779.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19426.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20434.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7341.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31034.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34753.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30865.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1814.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8589.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28812.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32392.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35988.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36622.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3574.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7757.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20126.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27738.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24704.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26125.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14506.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35519.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33203.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20262.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5254.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30498.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39686.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20471.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32324.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2203.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13194.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27465.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13124.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21653.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3339.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30096.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17816.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13891.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11140.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15154.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6271.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18703.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4451.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19696.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9966.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13679.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25980.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3557.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14865.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17349.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30168.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14196.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13241.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19947.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10417.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18467.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17183.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29974.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6631.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37239.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7771.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7059.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24326.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2017.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27068.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1957.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19734.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10901.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37508.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31775.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27980.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8004.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5709.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3674.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33762.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24727.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11290.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3039.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21806.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15345.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23195.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16016.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38742.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31231.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34296.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30627.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10512.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10636.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33741.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20710.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2123.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26999.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10533.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30831.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35529.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12434.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39669.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8144.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3125.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4123.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4595.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39617.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7036.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9092.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30048.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1645.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2520.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21478.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_831.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13589.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27264.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24778.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20261.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33987.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4313.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24925.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20711.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29807.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8367.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20292.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2934.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38489.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21823.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10072.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17047.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26213.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31901.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39231.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10167.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20632.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34881.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23854.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1622.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18873.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39424.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34184.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15112.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29224.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1332.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16820.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12886.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17508.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17368.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3756.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21597.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29813.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37987.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8057.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4225.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10283.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17732.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13899.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18148.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36306.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8344.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8586.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32462.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37061.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1064.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14230.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3658.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27705.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26036.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21416.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4991.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21727.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2127.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7107.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26198.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6297.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1040.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38461.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10971.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27600.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32140.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11231.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17120.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4090.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36837.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30297.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14502.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_750.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10747.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35671.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33227.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2676.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2109.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33118.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39604.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5403.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27657.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6650.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34566.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33525.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7228.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32363.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20410.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9073.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32070.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34743.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23941.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29537.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28787.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37946.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24439.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3497.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_583.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16338.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3922.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37960.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32988.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26980.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24899.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25354.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27037.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_683.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18302.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10121.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22377.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17813.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2889.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26747.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2712.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_835.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15197.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22878.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24541.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17928.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16499.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24480.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13926.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9285.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25938.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33428.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17069.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10290.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10983.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11650.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24938.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_288.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22022.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9641.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32442.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23940.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29478.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22432.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1776.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27402.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2438.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13540.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23581.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19214.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2995.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19740.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1161.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2215.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26487.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13992.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30439.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27487.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5240.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30386.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17773.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27248.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13153.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13681.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5007.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6253.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32466.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36998.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27959.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18529.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_170.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10341.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35703.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21747.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24702.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21835.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5824.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5720.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13997.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21869.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5424.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23074.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17623.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37528.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36058.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10095.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9815.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6199.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38771.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14989.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19884.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27108.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33827.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12718.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29659.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11128.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19287.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26226.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26081.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16003.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9091.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13172.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7208.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32393.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2778.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10574.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7946.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19614.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22819.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27163.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11810.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37780.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9830.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11403.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20155.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31708.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31670.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8894.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3095.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35278.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14496.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30595.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27309.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36053.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16177.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23518.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38723.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14836.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4713.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4276.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22268.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26639.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34054.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32945.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4809.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8680.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18319.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28352.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33226.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34199.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_164.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15576.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21807.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9337.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12871.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16050.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9571.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12621.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35998.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26918.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22633.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7806.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29833.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39763.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21648.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5463.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39107.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22375.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_55.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20058.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9086.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10621.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18850.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9031.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14204.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10584.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8575.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9835.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32739.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_373.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29873.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28419.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28041.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21443.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3520.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39947.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15829.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23386.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39264.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1438.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29789.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34066.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27716.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24362.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17277.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7548.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16841.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4277.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18084.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21360.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16426.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4128.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25034.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17842.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24524.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20048.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14336.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30469.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33581.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20879.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39653.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23397.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34657.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38987.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13773.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26988.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5436.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14633.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31811.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1522.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36366.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34631.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36249.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37247.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_880.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17754.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14376.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27914.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36981.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38725.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5268.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25777.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3053.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34021.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34814.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14061.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6624.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25971.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20322.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35290.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11328.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7206.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27664.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31835.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6795.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27785.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6287.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18784.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28601.jpg'),
# ...
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3791.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12461.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11841.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_922.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37268.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31279.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32863.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17603.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_567.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10400.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12596.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14637.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25011.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18391.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16393.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1599.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14212.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29691.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39197.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33210.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13207.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15785.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1551.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18415.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12883.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28264.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9407.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34334.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38108.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22405.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1595.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25576.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15056.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9249.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3246.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13417.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28197.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25731.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25136.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9560.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4585.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13221.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33414.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37134.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1289.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5689.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1759.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16700.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6823.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28579.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28716.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31668.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9545.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27503.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35869.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15237.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15003.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36667.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35635.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9679.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5360.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15519.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35854.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33643.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27346.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_14943.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32094.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10198.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17075.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11611.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6005.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6705.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23410.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1381.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27543.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3358.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32608.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5599.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24648.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21797.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16804.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9478.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2939.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26245.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4539.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1514.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34527.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4932.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17323.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2473.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18903.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38468.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22793.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4602.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_16893.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7629.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5234.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20907.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33271.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27015.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18922.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_40292.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38314.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_495.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27977.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4766.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33543.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17808.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25228.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33200.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38682.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23788.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13408.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27308.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37873.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10156.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37334.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22546.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10740.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39094.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30363.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33097.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18829.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27300.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1562.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26624.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12602.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30997.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21308.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36020.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_3790.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27850.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_29976.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8314.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6844.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7157.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1328.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_40241.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19439.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5893.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6915.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34655.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17638.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9469.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26505.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38751.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23859.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15404.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9643.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33776.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2343.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19547.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13820.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_145.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39564.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_15906.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33956.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10546.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12069.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_8697.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25949.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17561.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5933.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23860.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30912.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37025.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_22773.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11313.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38395.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12125.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20473.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25642.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19524.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23548.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34928.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13800.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36110.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_37382.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30646.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30917.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17671.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35094.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31990.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_5156.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9864.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_1632.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_27403.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_11811.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21110.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_7988.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21546.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23467.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17788.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_4833.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23275.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_31695.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39613.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_35106.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_6293.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17462.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_32994.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12206.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2671.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25479.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26186.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_30611.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_12262.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19888.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_39042.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23550.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_23985.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_26078.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21643.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25691.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24949.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34496.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_2353.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_9452.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28495.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_21009.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_38459.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13083.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_19808.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_25918.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_13433.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33100.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_946.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_20424.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18661.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_10719.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_34270.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_28752.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_18295.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24961.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_36205.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_24225.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_17504.jpg'),
#  PosixPath('/root/.fastai/data/planet/train-jpg/train_33831.jpg'),
#  ...]

# %%
df = pd.read_csv(path/'train_v2.csv')
df.head()
# Out:
#   image_name                                       tags
# 0    train_0                               haze primary
# 1    train_1            agriculture clear primary water
# 2    train_2                              clear primary
# 3    train_3                              clear primary
# 4    train_4  agriculture clear habitation primary road

# %% [markdown]
# To put this in a `DataBunch` while using the [data block API](https://docs.fast.ai/data_block.html), we then need to using `ImageList` (and not `ImageDataBunch`). This will make sure the model created has the proper loss function to deal with the multiple classes.

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %% [markdown]
# We use parentheses around the data block pipeline below, so that we can use a multiline statement without needing to add '\\'.

# %%
np.random.seed(42)
src = (ImageList.from_csv(path, 'train_v2.csv', folder='train-jpg', suffix='.jpg')
       .split_by_rand_pct(0.2)
       .label_from_df(label_delim=' '))

# %%
data = (src.transform(tfms, size=128)
        .databunch().normalize(imagenet_stats))

# %% [markdown]
# `show_batch` still works, and show us the different labels separated by `;`.

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# To create a `Learner` we use the same function as in lesson 1. Our base architecture is resnet50 again, but the metrics are a little bit differeent: we use `accuracy_thresh` instead of `accuracy`. In lesson 1, we determined the predicition for a given class by picking the final activation that was the biggest, but here, each activation can be 0. or 1. `accuracy_thresh` selects the ones that are above a certain threshold (0.5 by default) and compares them to the ground truth.
#
# As for Fbeta, it's the metric that was used by Kaggle on this competition. See [here](https://en.wikipedia.org/wiki/F1_score) for more details.

# %%
arch = models.resnet50

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f_score = partial(fbeta, thresh=0.2)
learn = cnn_learner(data, arch, metrics=[acc_02, f_score])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %% [markdown]
# We use the LR Finder to pick a good learning rate.

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='92' class='' max='506' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.18% [92/506 00:23<01:45 1.7882]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# Then we can fit the head of our network.

# %%
lr = 0.01

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.137519</td>
#       <td>0.112696</td>
#       <td>0.941511</td>
#       <td>0.900880</td>
#       <td>02:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.113051</td>
#       <td>0.097231</td>
#       <td>0.947034</td>
#       <td>0.914870</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.101433</td>
#       <td>0.092379</td>
#       <td>0.957556</td>
#       <td>0.920812</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.096221</td>
#       <td>0.088304</td>
#       <td>0.957301</td>
#       <td>0.923646</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.091759</td>
#       <td>0.086983</td>
#       <td>0.956851</td>
#       <td>0.925329</td>
#       <td>02:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-rn50')

# %% [markdown]
# ...And fine-tune the whole model:

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='506' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       16.80% [85/506 00:21<01:48 0.3315]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.097132</td>
#       <td>0.092393</td>
#       <td>0.954133</td>
#       <td>0.920244</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.094395</td>
#       <td>0.091056</td>
#       <td>0.956407</td>
#       <td>0.920783</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.089513</td>
#       <td>0.086459</td>
#       <td>0.957432</td>
#       <td>0.925532</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.086253</td>
#       <td>0.083300</td>
#       <td>0.958064</td>
#       <td>0.928577</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.079708</td>
#       <td>0.082824</td>
#       <td>0.958100</td>
#       <td>0.928322</td>
#       <td>02:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-rn50')

# %%
data = (src.transform(tfms, size=256)
        .databunch().normalize(imagenet_stats))

learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='86' class='' max='506' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.00% [86/506 00:43<03:34 0.2903]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-2/2

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.091284</td>
#       <td>0.085011</td>
#       <td>0.957359</td>
#       <td>0.926738</td>
#       <td>04:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.086054</td>
#       <td>0.084701</td>
#       <td>0.960745</td>
#       <td>0.926498</td>
#       <td>04:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.082887</td>
#       <td>0.084086</td>
#       <td>0.959532</td>
#       <td>0.927170</td>
#       <td>04:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.081742</td>
#       <td>0.081219</td>
#       <td>0.959670</td>
#       <td>0.930145</td>
#       <td>04:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.080554</td>
#       <td>0.080967</td>
#       <td>0.958827</td>
#       <td>0.929892</td>
#       <td>04:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-256-rn50')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.084499</td>
#       <td>0.084078</td>
#       <td>0.959554</td>
#       <td>0.928046</td>
#       <td>05:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.085999</td>
#       <td>0.084362</td>
#       <td>0.956320</td>
#       <td>0.927293</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.082941</td>
#       <td>0.082027</td>
#       <td>0.957432</td>
#       <td>0.928862</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.080031</td>
#       <td>0.080653</td>
#       <td>0.958326</td>
#       <td>0.930663</td>
#       <td>05:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.076743</td>
#       <td>0.080868</td>
#       <td>0.959895</td>
#       <td>0.931448</td>
#       <td>05:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2-256-rn50')

# %% [markdown]
# You won't really know how you're going until you submit to Kaggle, since the leaderboard isn't using the same subset as we have for training. But as a guide, 50th place (out of 938 teams) on the private leaderboard was a score of `0.930`.

# %%
learn.export()

# %% [markdown]
# ## fin

# %% [markdown]
# (This section will be covered in part 2 - please don't ask about it just yet! :) )

# %%
#! kaggle competitions download -c planet-understanding-the-amazon-from-space -f test-jpg.tar.7z -p {path}  
#! 7za -bd -y -so x {path}/test-jpg.tar.7z | tar xf - -C {path}
#! kaggle competitions download -c planet-understanding-the-amazon-from-space -f test-jpg-additional.tar.7z -p {path}  
#! 7za -bd -y -so x {path}/test-jpg-additional.tar.7z | tar xf - -C {path}

# %%
test = ImageList.from_folder(path/'test-jpg').add(ImageList.from_folder(path/'test-jpg-additional'))
len(test)
# Out:
# 61191

# %%
learn = load_learner(path, test=test)
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
thresh = 0.2
labelled_preds = [' '.join([learn.data.classes[i] for i,p in enumerate(pred) if p > thresh]) for pred in preds]

# %%
labelled_preds[:5]
# Out:
# ['agriculture cultivation partly_cloudy primary road',
#  'clear haze primary water',
#  'agriculture clear cultivation primary',
#  'clear primary',
#  'partly_cloudy primary']

# %%
fnames = [f.name[:-4] for f in learn.data.test_ds.items]

# %%
df = pd.DataFrame({'image_name':fnames, 'tags':labelled_preds}, columns=['image_name', 'tags'])

# %%
df.to_csv(path/'submission.csv', index=False)

# %%
! kaggle competitions submit planet-understanding-the-amazon-from-space -f {path/'submission.csv'} -m "My submission"
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/ubuntu/.kaggle/kaggle.json'
# 100%|██████████████████████████████████████| 2.18M/2.18M [00:02<00:00, 1.05MB/s]
# Successfully submitted to Planet: Understanding the Amazon from Space

# %% [markdown]
# Private Leaderboard score: 0.9296 (around 80th)
