# %% [markdown]
# <a href="https://colab.research.google.com/github/bksgupta/course-v3/blob/master/lesson3_imdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMDB

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# First let's download the dataset we are going to study. The [dataset](http://ai.stanford.edu/~amaas/data/sentiment/) has been curated by Andrew Maas et al. and contains a total of 100,000 reviews on IMDB. 25,000 of them are labelled as positive and negative for training, another 25,000 are labelled for testing (in both cases they are highly polarized). The remaning 50,000 is an additional unlabelled data (but we will find a use for it nonetheless).
#
# We'll begin with a sample we've prepared for you, so that things run quickly before going over the full dataset.

# %%
path = untar_data(URLs.IMDB_SAMPLE)
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/imdb_sample/texts.csv'),
#  PosixPath('/root/.fastai/data/imdb_sample/data_save.pkl')]

# %% [markdown]
# It only contains one csv file, let's have a look at it.

# %%
path
# Out:
# PosixPath('/root/.fastai/data/imdb_sample')

# %%
df = pd.read_csv(path/'texts.csv')
df.head()
# Out:
#       label                                               text  is_valid
# 0  negative  Un-bleeping-believable! Meg Ryan doesn't even ...     False
# 1  positive  This is a extremely well-made film. The acting...     False
# 2  negative  Every once in a long while a movie will come a...     False
# 3  positive  Name just says it all. I watched this movie wi...     False
# 4  negative  This movie succeeds at being one of the most u...     False

# %%
df['text'][1]
# Out:
# 'This is a extremely well-made film. The acting, script and camera-work are all first-rate. The music is good, too, though it is mostly early in the film, when things are still relatively cheery. There are no really superstars in the cast, though several faces will be familiar. The entire cast does an excellent job with the script.<br /><br />But it is hard to watch, because there is no good end to a situation like the one presented. It is now fashionable to blame the British for setting Hindus and Muslims against each other, and then cruelly separating them into two countries. There is some merit in this view, but it\'s also true that no one forced Hindus and Muslims in the region to mistreat each other as they did around the time of partition. It seems more likely that the British simply saw the tensions between the religions and were clever enough to exploit them to their own ends.<br /><br />The result is that there is much cruelty and inhumanity in the situation and this is very unpleasant to remember and to see on the screen. But it is never painted as a black-and-white case. There is baseness and nobility on both sides, and also the hope for change in the younger generation.<br /><br />There is redemption of a sort, in the end, when Puro has to make a hard choice between a man who has ruined her life, but also truly loved her, and her family which has disowned her, then later come looking for her. But by that point, she has no option that is without great pain for her.<br /><br />This film carries the message that both Muslims and Hindus have their grave faults, and also that both can be dignified and caring people. The reality of partition makes that realisation all the more wrenching, since there can never be real reconciliation across the India/Pakistan border. In that sense, it is similar to "Mr & Mrs Iyer".<br /><br />In the end, we were glad to have seen the film, even though the resolution was heartbreaking. If the UK and US could deal with their own histories of racism with this kind of frankness, they would certainly be better off.'

# %% [markdown]
# It contains one line per review, with the label ('negative' or 'positive'), the text and a flag to determine if it should be part of the validation set or the training set. If we ignore this flag, we can create a DataBunch containing this data in one line of code:

# %%
data_lm = TextDataBunch.from_csv(path, 'texts.csv')

# %%
data_lm.train_ds[0]
# Out:
# (Text [   2    5   86  331 ...   11 1861  122  172], Category 0)

# %% [markdown]
# By executing this line a process was launched that took a bit of time. Let's dig a bit into it. Images could be fed (almost) directly into a model because they're just a big array of pixel values that are floats between 0 and 1. A text is composed of words, and we can't apply mathematical functions to them directly. We first have to convert them to numbers. This is done in two differents steps: tokenization and numericalization. A `TextDataBunch` does all of that behind the scenes for you.
#
# Before we delve into the explanations, let's take the time to save the things that were calculated.

# %%
data_lm.save()

# %% [markdown]
# Next time we launch this notebook, we can skip the cell above that took a bit of time (and that will take a lot more when you get to the full dataset) and load those results like this:

# %%
data = load_data(path)

# %%
data_lm.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj raising xxmaj victor xxmaj vargas : a xxmaj review \n \n  xxmaj you know , xxmaj raising xxmaj victor xxmaj vargas is like sticking your hands into a big , steaming bowl of xxunk . xxmaj it 's warm and gooey , but you 're not sure if it feels right . xxmaj try as i might , no matter how warm and gooey xxmaj raising xxmaj</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup the xxup shop xxup around xxup the xxup corner is one of the xxunk and most feel - good romantic comedies ever made . xxmaj there 's just no getting around that , and it 's hard to actually put one 's feeling for this film into words . xxmaj it 's not one of those films that tries too hard , nor does it come up with</td>
#       <td>positive</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj now that xxmaj che(2008 ) has finished its relatively short xxmaj australian cinema run ( extremely limited xxunk screen in xxmaj sydney , after xxunk ) , i can xxunk join both xxunk of " xxmaj at xxmaj the xxmaj movies " in taking xxmaj steven xxmaj soderbergh to task . \n \n  xxmaj it 's usually satisfying to watch a film director change his style /</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this film sat on my xxmaj xxunk for weeks before i watched it . i dreaded a self - indulgent xxunk flick about relationships gone bad . i was wrong ; this was an xxunk xxunk into the screwed - up xxunk of xxmaj new xxmaj yorkers . \n \n  xxmaj the format is the same as xxmaj max xxmaj xxunk ' " xxmaj la xxmaj ronde</td>
#       <td>positive</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj many neglect that this is n't just a classic due to the fact that it 's the first xxup 3d game , or even the first xxunk - up . xxmaj it 's also one of the first stealth games , one of the xxunk definitely the first ) truly claustrophobic games , and just a pretty well - rounded gaming experience in general . xxmaj with graphics</td>
#       <td>positive</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Tokenization

# %% [markdown]
# The first step of processing we make the texts go through is to split the raw sentences into words, or more exactly tokens. The easiest way to do this would be to split the string on spaces, but we can be smarter:
#
# - we need to take care of punctuation
# - some words are contractions of two different words, like isn't or don't
# - we may need to clean some parts of our texts, if there's HTML code for instance
#
# To see what the tokenizer had done behind the scenes, let's have a look at a few texts in a batch.

# %%
data = TextClasDataBunch.from_csv(path, 'texts.csv')
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj raising xxmaj victor xxmaj vargas : a xxmaj review \n \n  xxmaj you know , xxmaj raising xxmaj victor xxmaj vargas is like sticking your hands into a big , xxunk bowl of xxunk . xxmaj it 's warm and gooey , but you 're not sure if it feels right . xxmaj try as i might , no matter how warm and gooey xxmaj raising xxmaj</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup the xxup shop xxup around xxup the xxup corner is one of the sweetest and most feel - good romantic comedies ever made . xxmaj there 's just no getting around that , and it 's hard to actually put one 's feeling for this film into words . xxmaj it 's not one of those films that tries too hard , nor does it come up with</td>
#       <td>positive</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj now that xxmaj che(2008 ) has finished its relatively short xxmaj australian cinema run ( extremely limited xxunk screen in xxmaj xxunk , after xxunk ) , i can xxunk join both xxunk of " xxmaj at xxmaj the xxmaj movies " in taking xxmaj steven xxmaj soderbergh to task . \n \n  xxmaj it 's usually satisfying to watch a film director change his style /</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this film sat on my xxmaj tivo for weeks before i watched it . i xxunk a self - indulgent xxunk flick about relationships gone bad . i was wrong ; this was an xxunk xxunk into the screwed - up xxunk of xxmaj new xxmaj yorkers . \n \n  xxmaj the format is the same as xxmaj max xxmaj xxunk ' " xxmaj la xxmaj ronde</td>
#       <td>positive</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj many neglect that this is n't just a classic due to the fact that it 's the first xxup 3d game , or even the first xxunk - up . xxmaj it 's also one of the first stealth games , one of the xxunk definitely the first ) truly claustrophobic games , and just a pretty well - rounded gaming experience in general . xxmaj with graphics</td>
#       <td>positive</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The texts are truncated at 100 tokens for more readability. We can see that it did more than just split on space and punctuation symbols:
# - the "'s" are grouped together in one token
# - the contractions are separated like this: "did", "n't"
# - content has been cleaned for any HTML symbol and lower cased
# - there are several special tokens (all those that begin by xx), to replace unknown tokens (see below) or to introduce different text fields (here we only have one).

# %% [markdown]
# ### Numericalization

# %% [markdown]
# Once we have extracted tokens from our texts, we convert to integers by creating a list of all the words used. We only keep the ones that appear at least twice with a maximum vocabulary size of 60,000 (by default) and replace the ones that don't make the cut by the unknown token `UNK`.
#
# The correspondance from ids to tokens is stored in the `vocab` attribute of our datasets, in a dictionary called `itos` (for int to string).

# %%
data.vocab.itos[:10]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  'the']

# %% [markdown]
# And if we look at what a what's in our datasets, we'll see the tokenized text as a representation:

# %%
data.train_ds[0][0]
# Out:
# Text [  2   5  75 132 ...  10 101 135  11]

# %% [markdown]
# But the underlying data is all numbers

# %%
data.train_ds[0][0].data[:10]
# Out:
# array([   2,    5,   75,  132,   10, 1977,  123,   10,   12, 1106])

# %% [markdown]
# ### With the data block API

# %% [markdown]
# We can use the data block API with NLP and have a lot more flexibility than what the default factory methods offer. In the previous example for instance, the data was randomly split between train and validation instead of reading the third column of the csv.
#
# With the data block API though, we have to manually call the tokenize and numericalize steps. This allows more flexibility, and if you're not using the defaults from fastai, the various arguments to pass will appear in the step they're revelant, so it'll be more readable.

# %%
data = (TextList.from_csv(path, 'texts.csv', cols='text')
                .split_from_df(col=2)
                .label_from_df(cols=0)
                .databunch())

# %% [markdown]
# ## Language model

# %% [markdown]
# Note that language models can use a lot of GPU, so you may need to decrease batchsize here.

# %%
bs=48

# %% [markdown]
# Now let's grab the full dataset for what follows.

# %%
path = untar_data(URLs.IMDB)
path.ls()
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-nlp/imdb.tgz
# [PosixPath('/root/.fastai/data/imdb/unsup'),
#  PosixPath('/root/.fastai/data/imdb/test'),
#  PosixPath('/root/.fastai/data/imdb/train'),
#  PosixPath('/root/.fastai/data/imdb/imdb.vocab'),
#  PosixPath('/root/.fastai/data/imdb/tmp_clas'),
#  PosixPath('/root/.fastai/data/imdb/tmp_lm'),
#  PosixPath('/root/.fastai/data/imdb/README')]

# %%
path
# Out:
# PosixPath('/root/.fastai/data/imdb')

# %%
(path/'train').ls()
# Out:
# [PosixPath('/root/.fastai/data/imdb/train/labeledBow.feat'),
#  PosixPath('/root/.fastai/data/imdb/train/unsupBow.feat'),
#  PosixPath('/root/.fastai/data/imdb/train/neg'),
#  PosixPath('/root/.fastai/data/imdb/train/pos')]

# %%
(path/'train/pos').ls()
# Out:
# [PosixPath('/root/.fastai/data/imdb/train/pos/3828_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6777_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3506_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5400_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8083_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8561_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5604_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1337_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10719_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5215_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4807_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7761_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/435_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/798_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6399_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1677_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10055_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6931_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11363_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12458_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7349_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1563_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7781_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10570_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4653_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7068_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7338_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7118_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9719_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/765_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7404_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5800_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4689_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4383_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8822_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9675_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6854_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2279_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2564_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11214_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/796_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10934_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3371_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7697_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4736_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1402_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6006_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7354_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11538_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8656_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11775_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11748_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3261_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8036_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1217_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1551_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1517_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1567_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7604_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6747_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1286_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2445_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8078_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1339_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10807_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10494_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1990_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2751_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12490_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5273_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7594_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3523_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5112_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1350_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8764_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11829_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9061_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8150_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12033_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6659_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7029_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5143_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9382_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8850_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12111_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1405_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10316_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9253_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12188_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10572_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9012_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10765_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12085_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11433_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9144_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3374_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2780_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11173_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7421_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4189_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1695_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10994_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10178_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4996_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7751_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7353_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9392_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9179_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5396_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5269_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4595_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1080_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6560_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4644_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9006_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1636_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10884_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1048_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12345_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8215_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9215_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2540_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6744_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3326_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8808_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9940_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10008_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4950_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11065_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10864_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11119_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7552_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11696_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9311_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12423_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10415_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6508_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7320_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8033_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4036_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6847_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9863_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5371_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8590_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/459_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7494_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9221_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7188_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4788_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6677_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3023_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3846_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/785_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10768_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5117_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4367_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5849_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12422_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11551_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8294_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10642_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10659_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3683_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10448_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8616_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7853_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6736_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3630_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1893_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4249_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3415_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11036_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1804_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4218_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6892_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6855_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1114_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10181_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/658_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12036_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12193_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7365_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11322_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/63_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3107_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10565_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7466_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/985_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4570_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10631_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7317_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3877_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3050_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5350_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10296_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5828_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1164_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9402_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3213_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4677_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8393_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3449_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9760_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3271_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7888_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8052_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9183_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2583_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4883_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3093_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1298_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7926_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6851_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7031_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2482_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3225_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/978_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5178_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11913_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2785_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8158_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7374_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10917_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5821_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7282_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5801_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3389_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10622_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8251_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4633_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8830_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11623_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11827_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5759_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6828_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11799_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9048_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11346_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6231_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7759_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7924_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/237_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4992_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12202_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11534_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1220_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8896_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/963_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/155_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3025_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10938_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5139_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9958_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5073_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/608_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8858_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4307_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6920_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8460_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/152_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10071_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2499_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5548_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2179_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8834_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/322_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7456_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4874_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2306_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6670_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/754_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9352_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10674_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11638_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1443_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10356_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/402_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10863_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10689_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8144_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9699_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11338_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12179_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/729_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4865_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2872_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5091_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9282_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11443_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11181_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3707_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10887_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10209_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2421_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4033_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1972_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/706_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10044_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7930_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5946_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11032_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9513_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8981_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5498_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12116_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11075_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2930_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5405_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2733_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11714_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6419_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2971_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4521_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9851_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4214_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3970_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5922_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/764_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10510_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8424_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11594_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8947_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11826_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6084_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11470_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9303_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7893_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8565_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7497_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2807_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6843_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6012_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2820_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6209_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4322_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11751_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3175_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/972_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/528_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7210_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6865_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4093_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2582_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2666_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7896_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3277_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7334_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3446_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6482_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12167_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7059_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4301_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/677_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1905_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1458_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9079_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9448_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3953_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6918_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11985_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3094_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5843_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8353_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/174_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2815_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7561_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3632_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5659_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6003_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7521_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/460_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4135_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4955_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9983_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5037_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5888_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6787_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12408_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5250_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5220_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11200_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4341_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8326_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1964_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11631_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9463_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/364_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1318_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/198_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10923_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4317_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12178_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9243_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/681_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2490_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6328_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1736_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/803_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3177_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4250_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10059_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4057_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5890_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1939_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6964_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3165_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3916_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3090_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12200_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1232_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11855_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11733_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4410_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3227_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4344_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1806_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9641_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9962_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10840_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10668_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9374_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1347_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1367_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/513_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8084_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5452_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3917_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10163_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7836_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/329_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9196_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9659_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11969_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7372_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4666_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2798_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9974_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8336_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1586_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7435_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12196_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9758_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11599_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10221_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7366_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10381_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5514_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3431_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1334_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5161_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8511_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9220_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2342_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12023_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8574_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8904_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9869_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5151_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7593_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7965_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6509_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1386_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10079_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6445_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9297_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5392_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3670_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2768_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12312_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1816_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6953_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7550_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4482_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6171_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8161_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8316_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5484_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9344_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11110_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9865_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11304_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1758_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8905_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10441_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7715_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8059_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9319_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7329_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6384_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5264_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/332_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8270_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4636_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/282_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8157_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2376_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6429_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4488_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10261_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4628_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3612_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5425_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1889_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7767_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11109_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7065_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10779_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3038_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1457_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2102_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4648_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4328_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6999_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12195_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11629_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10247_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5277_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5531_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4956_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9140_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9434_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10464_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4031_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2887_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1680_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5493_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7037_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12017_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9688_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4295_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5974_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11172_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/408_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6880_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4507_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4817_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8003_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1467_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10523_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6735_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11094_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7624_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5043_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9679_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4535_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8018_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9009_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10931_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5640_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10785_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/696_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1686_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/819_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8676_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10812_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2397_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10945_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6285_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8380_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10718_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12231_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/444_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8920_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4106_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8195_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9476_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6327_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7113_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11894_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2130_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10389_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7324_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8286_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3345_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5993_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10703_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7900_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7614_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9320_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1566_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12468_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5532_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6773_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10290_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/676_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12378_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2715_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8517_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5080_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7125_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5413_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8089_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7262_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1710_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1236_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8173_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7602_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11932_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10814_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5704_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5474_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8541_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5132_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11887_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/171_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9209_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1013_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11038_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2487_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10093_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10669_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1149_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12057_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10875_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10504_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5799_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1336_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11716_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2990_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3226_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9423_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7680_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/440_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1135_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2056_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/645_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2533_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3834_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7898_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6676_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8432_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5883_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3603_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4371_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1564_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10479_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4118_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2123_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10836_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/944_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9539_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2644_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12363_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4312_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2914_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11150_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10539_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10256_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4374_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/406_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3386_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1289_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11213_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11698_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1659_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9482_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7157_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4730_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2946_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12457_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11747_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10964_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/590_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/53_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8889_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/370_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9342_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6866_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7430_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7186_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5122_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8407_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4409_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/716_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10308_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/110_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6573_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8397_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7975_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1786_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5682_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5005_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10048_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7543_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/956_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/967_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11359_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5164_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3054_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9406_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11554_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/902_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3511_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5249_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12321_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3382_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9013_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10722_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11043_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5278_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1195_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11622_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9452_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/290_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2997_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9997_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7592_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/759_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9333_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11302_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9944_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1042_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12182_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/736_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5292_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8622_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2678_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/156_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10713_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4765_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11785_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4751_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5627_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8490_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7967_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9207_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2204_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/858_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9146_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9176_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2650_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7490_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7966_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4487_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1666_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2142_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10423_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11456_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8436_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6976_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1590_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12435_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2200_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5705_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7978_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10670_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4957_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5879_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12342_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/879_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4749_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3106_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10530_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12367_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9899_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7360_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/685_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1262_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5262_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6622_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3058_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7406_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12132_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10733_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5438_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4167_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6106_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8309_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11912_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12000_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11951_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9769_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10920_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7488_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10021_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10787_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5343_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6027_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6125_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9386_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9401_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1118_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6486_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1587_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5173_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10257_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9409_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8345_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9128_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4794_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4489_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10038_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11367_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8963_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2572_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5331_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9164_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6820_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2199_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2752_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6972_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6052_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1807_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1676_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9747_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1081_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4226_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8775_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11700_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1485_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3409_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7142_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/591_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8828_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1722_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3912_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5666_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/143_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4729_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8800_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5348_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12352_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9725_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6821_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/979_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3039_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11807_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11634_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/45_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4464_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10888_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6996_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1671_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5491_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8581_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11469_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8409_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8412_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4122_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5907_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6300_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12138_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8010_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7132_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9942_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5582_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2119_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7277_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8946_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1211_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1119_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7783_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2472_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10484_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5873_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9159_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11421_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7042_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/489_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11953_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12139_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/373_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4577_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4670_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1702_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8049_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3064_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1037_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7452_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6105_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8652_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3913_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11340_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/275_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10433_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/558_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8119_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/901_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7667_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10164_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7677_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4116_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5669_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3532_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1238_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7721_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3156_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5521_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2568_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7120_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11737_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8400_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1418_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4559_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5749_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9689_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3395_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2836_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10119_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4327_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3399_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2442_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5386_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3063_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10943_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9952_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10853_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2033_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3573_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6365_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3705_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2910_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9229_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11269_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7240_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10143_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11398_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6877_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8068_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3677_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4731_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9872_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6424_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12394_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/173_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12365_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4798_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10355_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2711_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1914_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4920_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11190_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1553_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4987_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8223_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11344_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7146_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1797_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1340_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1309_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8463_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11031_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2393_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/833_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7057_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4198_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10376_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3580_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11249_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5736_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3185_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8504_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3500_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5487_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3206_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/104_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/12441_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11878_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4211_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8425_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1896_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2652_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7569_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1658_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/7654_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9666_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4762_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11544_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10666_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9045_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6400_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6930_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5258_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2684_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2566_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11276_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2535_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6526_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3267_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10105_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2857_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6004_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/9698_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/2560_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/8584_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/4021_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/10260_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1056_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11339_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/11473_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/1461_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3942_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3576_9.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5167_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6862_10.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/5716_8.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/6200_7.txt'),
#  PosixPath('/root/.fastai/data/imdb/train/pos/3285_10.txt'),
#  ...]

# %% [markdown]
# The reviews are in a training and test set following an imagenet structure. The only difference is that there is an `unsup` folder on top of `train` and `test` that contains the unlabelled data.
#
# We're not going to train a model that classifies the reviews from scratch. Like in computer vision, we'll use a model pretrained on a bigger dataset (a cleaned subset of wikipedia called [wikitext-103](https://einstein.ai/research/blog/the-wikitext-long-term-dependency-language-modeling-dataset)). That model has been trained to guess what the next word is, its input being all the previous words. It has a recurrent structure and a hidden state that is updated each time it sees a new word. This hidden state thus contains information about the sentence up to that point.
#
# We are going to use that 'knowledge' of the English language to build our classifier, but first, like for computer vision, we need to fine-tune the pretrained model to our particular dataset. Because the English of the reviews left by people on IMDB isn't the same as the English of wikipedia, we'll need to adjust the parameters of our model by a little bit. Plus there might be some words that would be extremely common in the reviews dataset but would be barely present in wikipedia, and therefore might not be part of the vocabulary the model was trained on.

# %% [markdown]
# This is where the unlabelled data is going to be useful to us, as we can use it to fine-tune our model. Let's create our data object with the data block API (next line takes a few minutes).

# %%
data_lm = (TextList.from_folder(path)
           #Inputs: all the text files in path
            .filter_by_folder(include=['train', 'test', 'unsup']) 
           #We may have other temp folders that contain text files so we only keep what's in train and test
            .split_by_rand_pct(0.1)
           #We randomly split and keep 10% (10,000 reviews) for validation
            .label_for_lm()           
           #We want to do a language model so we label accordingly
            .databunch(bs=bs))
data_lm.save('data_lm.pkl')

# %% [markdown]
# We have to use a special kind of `TextDataBunch` for the language model, that ignores the labels (that's why we put 0 everywhere), will shuffle the texts at each epoch before concatenating them all together (only for training, we don't shuffle for the validation set) and will send batches that read that text in order with targets that are the next word in the sentence.
#
# The line before being a bit long, we want to load quickly the final ids by using the following cell.

# %%
data_lm = load_data(path, 'data_lm.pkl', bs=bs)

# %%
data_lm.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>movie and that xxmaj william xxmaj shatner ( aka xxmaj captain xxmaj kirk ) was in it . xxmaj but first and foremost i thought that the fact that the used a " high priest of the church of xxmaj satan " as a technical adviser for the film just really peeked my curiosity for this film . \n \n  xxmaj the story is about a satanist cult lead</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>handle their unenviable assignment . xxmaj you might want to admire xxmaj james xxmaj craig ( as xxmaj haines ) 's admirable physique , during his shirtless scene . xxmaj or , you could observe how space flight affects ladies ' hairstyles . xxmaj casey xxmaj kasem and xxmaj mike xxmaj farrell have cameos . xxbos i saw xxmaj keane at the 42nd annual xxmaj new xxmaj york xxmaj film</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>that the stereotypical young blonde hero who arrives on the scene in the middle will be the one to save the day . xxmaj from a purely artistic point of view i 've seen much worse even in the last month , but why waste time on this when there are so many other superior movies out there calling for your attention ? xxmaj in fact , some of them</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>commercials . xxmaj yes , it all starts out as a usual xxup mtv xxmaj real xxmaj world episode , where everyone is arriving and introducing themselves then they are invited to a real world challenge , get kidnapped by some lunatic and get " real " tortured in somekind of a jailhouse . xxmaj by the way , if you were paying attention , the people that arrived together</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>provide our minds with cool , ass - kicking violence and head smashing , skull crashing brawls . xxmaj but n xxrep 7 o . xxmaj instead we get a vision of " cool fight - scenes " from a cameraman who likely has studied in the filming - school of blind , inbred orphan monkeys who did n't fit to write xxmaj shakespeare in a government secret project .</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can then put this in a learner object very easily with a model loaded with the pretrained weights. They'll be downloaded the first time you'll execute the following line and stored in `~/.fastai/models/` (or elsewhere if you specified different paths in your config file).

# %%
learn = language_model_learner(data_lm, AWD_LSTM, drop_mult=0.3)
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-modelzoo/wt103-fwd.tgz

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='8045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.23% [99/8045 00:16<22:26 11.1515]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(skip_end=15)

# %%
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.161912</td>
#       <td>4.023961</td>
#       <td>0.295688</td>
#       <td>23:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('fit_head')

# %%
learn.load('fit_head');

# %% [markdown]
# To complete the fine-tuning, we can then unfeeze and launch a new training.

# %%
learn.unfreeze()

# %%
# learn.fit_one_cycle(10, 1e-3, moms=(0.8,0.7))
learn.fit_one_cycle(1, 1e-3, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.801913</td>
#       <td>3.736197</td>
#       <td>0.329299</td>
#       <td>26:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('fine_tuned')

# %% [markdown]
# How good is our model? Well let's try to see what it predicts after a few given words.

# %%
learn.load('fine_tuned');

# %%
TEXT = "I liked this movie because"
N_WORDS = 40
N_SENTENCES = 2

# %%
print("\n".join(learn.predict(TEXT, N_WORDS, temperature=0.75) for _ in range(N_SENTENCES)))
# Out:
# I liked this movie because of the portrayal of the Unsure or Black Napoleon and how it deals with the portrays of Black and White . It shows that the race , the course , was well , great
# I liked this movie because the only good thing i had was about this movie . The plot was very thin and would have been better if it had been told in a more laughable way . It showed exactly how little the

# %% [markdown]
# We have to save not only the model, but also its encoder, the part that's responsible for creating and updating the hidden state. For the next part, we don't care about the part that tries to guess the next word.

# %%
learn.save_encoder('fine_tuned_enc')

# %% [markdown]
# ## Classifier

# %% [markdown]
# Now, we'll create a new data object that only grabs the labelled data and keeps those labels. Again, this line takes a bit of time.

# %%
path = untar_data(URLs.IMDB)

# %%
data_clas = (TextList.from_folder(path, vocab=data_lm.vocab)
             #grab all the text files in path
             .split_by_folder(valid='test')
             #split by train and valid folder (that only keeps 'train' and 'test' so no need to filter)
             .label_from_folder(classes=['neg', 'pos'])
             #label them all with their folders
             .databunch(bs=bs))

data_clas.save('data_clas.pkl')

# %%
data_clas = load_data(path, 'data_clas.pkl', bs=bs)

# %%
data_clas.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj match 1 : xxmaj tag xxmaj team xxmaj table xxmaj match xxmaj bubba xxmaj ray and xxmaj spike xxmaj dudley vs xxmaj eddie xxmaj guerrero and xxmaj chris xxmaj benoit xxmaj bubba xxmaj ray and xxmaj spike xxmaj dudley started things off with a xxmaj tag xxmaj team xxmaj table xxmaj match against xxmaj eddie xxmaj guerrero and xxmaj chris xxmaj benoit . xxmaj according to the rules</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <td>xxbos * * * xxmaj warning - this review contains " plot spoilers , " though nothing could " spoil " this movie any more than it already is . xxmaj it really xxup is that bad . * * * \n \n  xxmaj before i begin , i 'd like to let everyone know that this definitely is one of those so - incredibly - bad - that</td>
#       <td>neg</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj pier xxmaj paolo xxmaj pasolini , or xxmaj pee - pee - pee as i prefer to call him ( due to his love of showing male genitals ) , is perhaps xxup the most overrated xxmaj european xxmaj marxist director - and they are thick on the ground . xxmaj how anyone can see " art " in this messy , cheap sex - romp concoction is</td>
#       <td>neg</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj billy xxmaj chung xxmaj siu xxmaj hung 's ( the bloody swordplay film xxmaj assassin from 1993 ) film xxmaj love xxmaj to xxmaj kill ( xxmaj hong xxmaj kong , 1993 ) is among the strongest products of the xxmaj category xxup iii boom that inhabited the xxup hk cinema in early nineties . xxmaj it consisted of films with strong sex , nudity and violence ,</td>
#       <td>neg</td>
#     </tr>
#     <tr>
#       <td>xxbos * xxmaj some spoilers * \n \n  xxmaj this movie is sometimes subtitled " xxmaj life xxmaj everlasting . " xxmaj that 's often taken as reference to the final scene , but more accurately describes how dead and buried this once - estimable series is after this sloppy and illogical send - off . \n \n  xxmaj there 's a " hey kids , let 's</td>
#       <td>neg</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can then create a model to classify those reviews and load the encoder we saved before.

# %%
learn = text_classifier_learner(data_clas, AWD_LSTM, drop_mult=0.5)
learn.load_encoder('fine_tuned_enc')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (25000 items)
# x: TextList
# xxbos i was unlucky enough to have seen this at the xxmaj sidewalk xxmaj film xxmaj festival . xxmaj sidewalk as a whole was a disappointment and this movie was the final nail in the coffin . xxmaj being a devout fan of xxmaj lewis xxmaj carroll 's ' xxmaj alice ' books i was very excited about this movie 's premier , which only made it that much more uncomfortable to watch . xxmaj normally i 'm enthusiastic about modern re - tellings if they are treated well . xxmaj usually it 's interesting to see the parallels between the past and present within a familiar story . xxmaj unfortunately this movie was less of a modern retelling and more of a pop culture perversion . xxmaj the adaptation of the original 's characters seemed juvenile and usually proved to be horribly annoying . xxmaj it probably did n't help that the actors were n't very good either . xxmaj most performances were ridiculously over the top , which i assume was either due to bad direction or an effort to make up for a bad script . i did not laugh once through out the duration of the film . xxmaj all of the jokes were outdated references to not so current events that are sure to lose their poignancy as time goes by . xxmaj really , the only highlight of the film was the opening sequence in which the white rabbit is on his way to meet xxmaj alice , but even then the score was a poor imitation of xxmaj danny xxmaj elfman 's work . xxmaj also , i 'd have to say that the conversion of the xxunk game into a rave dance - off was awful . xxmaj it was with out a doubt the low point of the film .
#
#   xxmaj what a joke . xxmaj do n't see this movie . xxmaj after its conclusion i was genuinely angry .,xxbos xxmaj did anyone else feel as betrayed as i did ? xxmaj the first hour or so was pretty solid but the last . xxmaj oh my god . xxmaj it seemed like it was predictable and cheesy . xxmaj not grandiose and epic like the entire run of the show has been . xxmaj most reviews have read have been glowing but i really ca n't understand why . i had seriously predicted that general ending xxup way earlier on but then retracted it because i thought " xxmaj no , they would never do that , that 's xxup far too lame . " i can hardly stand it . i feel so unsatisfied . i think i 'm about to walk out the door to go sell every season i own . xxmaj someone please . xxmaj change my mind . i want to love this . xxup so bad . xxmaj someone tell me why i 'm wrong . xxmaj great show . xxmaj terrible ending .,xxbos xxmaj you get 5 writers together , have each write a different story with a different genre , and then you try to make one movie out of it . xxmaj it 's action , it 's adventure , it 's sci - fi , it 's western , it 's a mess . xxmaj sorry , but this movie absolutely stinks . 4.5 is giving it an xxunk high rating . xxmaj that said , it 's movies like this that make me think i could write movies , and i can barely write .,xxbos a good cast is appallingly wasted in this slower than molasses and haphazardly xxunk comedy . xxmaj peter xxmaj ustinov tries hard here to bring something to life but the result is a dour bore that misses all the right beats that might have made it watchable . xxmaj regardless of the favorable comments here , this film is awful . xxmaj badly directed . xxmaj badly edited . xxmaj badly acted . xxmaj badly written . xxmaj you need to sit through a hundred movies to come across one this bad .
#
#   xxmaj the muddled and excruciatingly xxunk plot concerns xxmaj ustinov conning his way into an xxmaj american insurance company in order to hack their computer and embezzle millions of pounds . xxmaj how he does it is beyond lameness and credibility ( he just learns his computer skills seemingly overnight by reading some pamphlets , and xxunk computer expert xxmaj robert xxmaj morley into going to xxmaj south xxmaj america and stealing his identity ) .
#
#   xxmaj as a side plot , xxmaj ustinov romances fellow loner xxmaj maggie xxmaj smith , who just happens to become his secretary by chance after he gets a flat in her building . xxmaj she ends up sharing scenes that have sexual undertones with xxmaj bob xxmaj newhart that go nowhere , while xxmaj ustinov goes about grafting the money bit by bit and trying to keep one step ahead of xxmaj newhart and xxmaj karl xxmaj malden . xxmaj then he xxmaj marries xxmaj smith and they fly off to xxmaj brazil , which has become the staple finale of almost every xxmaj british caper comedy since ( xxmaj nuns on the xxmaj run ? a xxmaj fish xxmaj called xxmaj wanda ? )
#
#   xxmaj the surprise twist of an ending is more laughable than everything that came before . xxmaj by the end i was thinking i must be truly off my rocker to stick out drivel like this . xxmaj even a cameo by xxmaj cesar xxmaj romero did n't help it . xxmaj one of the most unfunny , poorly paced ' comedies ' i 've ever seen , and certainly the worst caper . xxmaj do n't waste your time . xxmaj if you love this you need to see better films .,xxbos xxmaj slashers xxrep 5 . well if you like horrors its definitely one to see , otherwise do n't even bother . xxmaj it is completely obvious that this film has an extremely low budget , xxmaj for instance it looks as if the entire film has been shot in a warehouse somewhere , and on numerous occasions you will see the mike boom shadow and the camera mans shadow , trust me you wo nt need to look for them . xxmaj also try to ignore the cheesy actors , if that s what you call xxunk basic outline is a few people decide to go on a game show where they have to survive a night in a big maze due to their being 3 killers on the loose and whoever live 's at the end gets rich . xxmaj now there is something about this film that keeps you watching and rarely do you find that with a cheap budget horror these days , xxmaj for example when i watched it i thought to my self i would'nt mind having a go at this game ! especially for $ xxunk . so anyway i would recommend you watch it and make up your own mind .
# y: CategoryList
# neg,neg,neg,neg,neg
# Path: /root/.fastai/data/imdb;
#
# Valid: LabelList (25000 items)
# x: TextList
# xxbos xxmaj really , xxup really ... xxmaj what pleases audience ( american one ! ) in this so called show is totally beyond me . xxmaj what can we learn from these series :
#
#   1 . xxmaj each casino there is spending about 2 - 3 billion bucks every year to rent a satellite and enormous quantity of hi tech high resolution cameras for their security team . xxmaj let xxup fbi bites the dust of them .
#
#   2 . xxmaj every security employee must have voluptuous breasts , of course natural ones . xxmaj the tits must be shown all the time otherwise they will lose their job .
#
#   3 . xxmaj if the employee happens to be a male , he needs to get breasts implanted , then go to step 2 .
#
#   4 . xxmaj only in xxmaj hollywood one can blatantly rip off other show 's ideas then implement them as their own and call all this crap " original " and " art " .
#
#   5 . xxmaj every security with tits bigger than xxup xxunk is considered immortal and can not die .
#
#   i really would like to have the opportunity to vote with minus values . -10 / 10 for this one !,xxbos xxmaj in short this movie was awful .
#
#   i understand it 's a xxmaj disney movie , which are generally shallow movies with mediocre plots and bad acting . xxup however , i must say this is the worst of all xxmaj disney movies , with bad acting , xxup lots xxup of xxup irritating xxup shrieking xxup teen xxunk god ) , and an extremely unrealistic plot . xxmaj even as a 12 year old there is no way i would have liked this movie . xxmaj the only way this movie could have been any worse is if they attempted to put it in theaters or tried to sell it in a local video store .
#
#   xxmaj do yourself a favor and change the channel before watching this , no matter how bored you are on a xxmaj sunday afternoon .,xxbos xxmaj poor xxmaj casper xxmaj van xxmaj dien , his career has slid a long way from xxmaj tarzan and xxmaj starship xxmaj troopers .
#
#   xxmaj in xxmaj meltdown he 's a policeman who just happens to be dating xxup tv reporter xxmaj stefanie xxmaj von xxmaj xxunk and her brother is a scientist who 's trying to deal with a speeding comment headed for xxmaj earth . xxmaj but in the runaway comet business , even a near miss causes some real problems as the xxmaj earth 's orbit goes out of kilter .
#
#   xxmaj from the survival of the xxmaj earth we go to the survival of xxmaj van xxmaj dien and his immediate family . xxmaj his daughter 's gangbanger boyfriend , xxmaj ryan mcdonell actually proves to be of some use especially when he suspects a guy he knows as a crooked cop might mean the xxmaj van xxmaj dien group a lot of harm .
#
#   xxmaj my only question here is , why did n't they have xxmaj bruce xxmaj willis , xxmaj billy xxmaj bob xxmaj thornton and the rest of that crew to deal with the nasty comet ?
#
#   xxmaj pass this one up folks .,xxbos xxmaj norris plays a xxmaj chicago cop who stumbles upon a devil 's apprentice ? who wants to , well , create xxmaj xxunk . xxmaj he eventually kills the creature by , get this , throwing a solid gold 24 inch spike , not very sharp , about twenty feet , hard enough to penetrate the chest . xxmaj unlikely ? xxmaj so is the rest of the movie . xxmaj much of it consists of xxup cn and his sidekick driving cars and talking nonsense . xxmaj the xxmaj israeli ( or xxmaj arab ) kid is there ostensibly to humanize xxup cn . xxup ok . xxmaj does n't work , makes no sense , and advances the plot , so - called , not one bit . xxmaj also , no cops ever every get invited out of the country to be interviewed by other cops . xxmaj it is ridiculous as a premise . xxmaj the whole thing is bad . xxmaj unfortunately , it 's not so bad as to be entertainingly bad or campy . xxmaj just plain bad . xxmaj but -- one can see how xxmaj norris was trying to find his way to the successful xxmaj walker : xxmaj texas xxmaj ranger series .,xxbos xxmaj for those of you who have never heard of the movie until now ( of which , i presume there are many lucky people who have n't ) , i 'll summarise it for you . xxmaj ryan xxmaj gosling plays the titular character of xxmaj leland , who also serves as the film 's narrator ( a la xxmaj kevin xxmaj spacey in xxmaj american xxmaj beauty , but without the intelligent observations on life ) . xxmaj leland goes to jail for stabbing a retarded kid to death , and the movie attempts to figure out why he did it . xxmaj he seems to be a nice boy ( if not mentally absent ) , and is portrayed by xxmaj gosling with a complete lack of violence , anger , or agenda ( and if you 're waiting for him to reveal his sinister side later in the movie , do n't waste your time-- it 's not that kind of movie ) . xxmaj once in juvenile prison , xxmaj leland goes to classes taught by xxmaj pearl xxmaj madison , ably portrayed by xxmaj don xxmaj cheadle ( who is incapable of anything but quality , even when in bad movies ) . xxmaj pearl attempts to unlock the mystery of xxmaj leland in an attempt to figure out how such a kid could do such a thing , and so he could write a book about it later ( along with being a juvenile prison teacher , xxmaj pearl is also an aspiring author ) .
#
#   xxmaj the relationship between xxmaj leland and xxmaj pearl is the driving narrative behind the film , as their talks unveil xxmaj leland 's past to the audience . xxmaj however , to call it the central focus would imply that this meandering film had one . xxmaj it does not . xxmaj the xxmaj united xxmaj states of xxmaj leland boasts an impressive cast , which seems to be to the detriment of the film . xxmaj it seems as though writer / director xxmaj matthew xxmaj ryan xxmaj hodge ( do n't worry that you have n't heard of him , he 's never done anything ) had to give xxup every character a personal story arc and personality flaw in order to get the actors to play them . xxmaj most of these traits and stories are clichéd , and most go underdeveloped and unresolved .
#
#   i 'll try and break them down here : xxmaj martin xxmaj donovan and xxmaj ann xxmaj xxunk are the parents of the slain retarded boy ( i love how the movie kept calling the kid " retarded " , never " mentally disabled " . xxmaj that part made me laugh inside ) , they apparently have a cold relationship , because all suburban marriages in contemporary cinema must be cold . xxmaj their other two kids are xxmaj michelle xxmaj williams , who is apparently an aspiring actress about to attend college , and xxmaj jena xxmaj malone , who plays the same troubled teen - archetype she always plays , this time with a heroine addiction . xxmaj malone was also the girlfriend of xxmaj leland , which gives him his link to his victim . xxmaj williams ' boyfriend , who was orphaned and came to live with the family , and is a baseball player looking to go to the same college as his girlfriend , is played by xxmaj chris xxmaj klein . xxmaj he ends up doing more with his character than any of the other bit players , managing to steal the movie at times . xxmaj lena xxmaj olin is xxmaj leland 's mother , who seems to be perpetually sad for some reason . xxmaj kevin xxmaj spacey ( also the executive producer ) is xxmaj leland 's cold and absentee father , who is a famed novelist . xxmaj eventually , xxmaj sherilyn xxmaj fenn will show up to put a wrinkle in xxmaj leland 's story-- if you even care at that point . xxmaj oh yeah , and there 's a drug - dealing ex - boyfriend , a couple of fellow xxunk , and a co - worker of xxmaj pearl 's with whom he has an affair on his long distance girlfriend with ( played by xxmaj kerry xxmaj washington ) .
#
#   xxmaj sorry if all that synopsis and character breakdown took so long . xxmaj if it seemed meaningless and boring , then you 've just experienced a bit of what i did during the 108 minutes i spent watching the movie . xxmaj but the unruly supporting cast of over - wrought clichés is the least of this film 's crimes . xxmaj the biggest one is that the whole exercise is entirely pointless . xxmaj we are n't given a fascinating look into a troubled mind , we are n't given an effective explanation , we are n't given much of anything . xxmaj given that it sucked so much , i 'm gon na go ahead and spoil the ending for you so that you never have to see it : xxmaj leland stabbed the retard because all xxmaj leland could see in the world was sadness , and wanted to spare xxmaj corky ( or whatever the victim 's name was ) the sadness in his eyes . xxmaj it 's like the worst emo band in the world made an album , and titled it " xxmaj the xxmaj world xxmaj is xxmaj sad , xxmaj so i xxmaj killed a xxmaj retard " . xxmaj oh , and xxmaj leland dies in the end , in a sequence so reliant of unbelievable coincidences that it would have ruined the movie , if the movie did n't already suck . xxmaj of course he dies in the end , because that made the movie so deep .
#
#   i 'm giving the movie 2 stars , because the actors themselves all did a pretty good job with the junk they were given . xxmaj the scenes with xxmaj cheadle and xxmaj gosling together were even interesting on some levels . xxmaj but , to paraphrase the film itself , you have to believe that movies are more than the sum of their parts , kiddo .
# y: CategoryList
# neg,neg,neg,neg,neg
# Path: /root/.fastai/data/imdb;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(60000, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(60000, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f11fc2b2d90>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/root/.fastai/data/imdb'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (25000 items)
# x: TextList
# xxbos i was unlucky enough to have seen this at the xxmaj sidewalk xxmaj film xxmaj festival . xxmaj sidewalk as a whole was a disappointment and this movie was the final nail in the coffin . xxmaj being a devout fan of xxmaj lewis xxmaj carroll 's ' xxmaj alice ' books i was very excited about this movie 's premier , which only made it that much more uncomfortable to watch . xxmaj normally i 'm enthusiastic about modern re - tellings if they are treated well . xxmaj usually it 's interesting to see the parallels between the past and present within a familiar story . xxmaj unfortunately this movie was less of a modern retelling and more of a pop culture perversion . xxmaj the adaptation of the original 's characters seemed juvenile and usually proved to be horribly annoying . xxmaj it probably did n't help that the actors were n't very good either . xxmaj most performances were ridiculously over the top , which i assume was either due to bad direction or an effort to make up for a bad script . i did not laugh once through out the duration of the film . xxmaj all of the jokes were outdated references to not so current events that are sure to lose their poignancy as time goes by . xxmaj really , the only highlight of the film was the opening sequence in which the white rabbit is on his way to meet xxmaj alice , but even then the score was a poor imitation of xxmaj danny xxmaj elfman 's work . xxmaj also , i 'd have to say that the conversion of the xxunk game into a rave dance - off was awful . xxmaj it was with out a doubt the low point of the film .
#
#   xxmaj what a joke . xxmaj do n't see this movie . xxmaj after its conclusion i was genuinely angry .,xxbos xxmaj did anyone else feel as betrayed as i did ? xxmaj the first hour or so was pretty solid but the last . xxmaj oh my god . xxmaj it seemed like it was predictable and cheesy . xxmaj not grandiose and epic like the entire run of the show has been . xxmaj most reviews have read have been glowing but i really ca n't understand why . i had seriously predicted that general ending xxup way earlier on but then retracted it because i thought " xxmaj no , they would never do that , that 's xxup far too lame . " i can hardly stand it . i feel so unsatisfied . i think i 'm about to walk out the door to go sell every season i own . xxmaj someone please . xxmaj change my mind . i want to love this . xxup so bad . xxmaj someone tell me why i 'm wrong . xxmaj great show . xxmaj terrible ending .,xxbos xxmaj you get 5 writers together , have each write a different story with a different genre , and then you try to make one movie out of it . xxmaj it 's action , it 's adventure , it 's sci - fi , it 's western , it 's a mess . xxmaj sorry , but this movie absolutely stinks . 4.5 is giving it an xxunk high rating . xxmaj that said , it 's movies like this that make me think i could write movies , and i can barely write .,xxbos a good cast is appallingly wasted in this slower than molasses and haphazardly xxunk comedy . xxmaj peter xxmaj ustinov tries hard here to bring something to life but the result is a dour bore that misses all the right beats that might have made it watchable . xxmaj regardless of the favorable comments here , this film is awful . xxmaj badly directed . xxmaj badly edited . xxmaj badly acted . xxmaj badly written . xxmaj you need to sit through a hundred movies to come across one this bad .
#
#   xxmaj the muddled and excruciatingly xxunk plot concerns xxmaj ustinov conning his way into an xxmaj american insurance company in order to hack their computer and embezzle millions of pounds . xxmaj how he does it is beyond lameness and credibility ( he just learns his computer skills seemingly overnight by reading some pamphlets , and xxunk computer expert xxmaj robert xxmaj morley into going to xxmaj south xxmaj america and stealing his identity ) .
#
#   xxmaj as a side plot , xxmaj ustinov romances fellow loner xxmaj maggie xxmaj smith , who just happens to become his secretary by chance after he gets a flat in her building . xxmaj she ends up sharing scenes that have sexual undertones with xxmaj bob xxmaj newhart that go nowhere , while xxmaj ustinov goes about grafting the money bit by bit and trying to keep one step ahead of xxmaj newhart and xxmaj karl xxmaj malden . xxmaj then he xxmaj marries xxmaj smith and they fly off to xxmaj brazil , which has become the staple finale of almost every xxmaj british caper comedy since ( xxmaj nuns on the xxmaj run ? a xxmaj fish xxmaj called xxmaj wanda ? )
#
#   xxmaj the surprise twist of an ending is more laughable than everything that came before . xxmaj by the end i was thinking i must be truly off my rocker to stick out drivel like this . xxmaj even a cameo by xxmaj cesar xxmaj romero did n't help it . xxmaj one of the most unfunny , poorly paced ' comedies ' i 've ever seen , and certainly the worst caper . xxmaj do n't waste your time . xxmaj if you love this you need to see better films .,xxbos xxmaj slashers xxrep 5 . well if you like horrors its definitely one to see , otherwise do n't even bother . xxmaj it is completely obvious that this film has an extremely low budget , xxmaj for instance it looks as if the entire film has been shot in a warehouse somewhere , and on numerous occasions you will see the mike boom shadow and the camera mans shadow , trust me you wo nt need to look for them . xxmaj also try to ignore the cheesy actors , if that s what you call xxunk basic outline is a few people decide to go on a game show where they have to survive a night in a big maze due to their being 3 killers on the loose and whoever live 's at the end gets rich . xxmaj now there is something about this film that keeps you watching and rarely do you find that with a cheap budget horror these days , xxmaj for example when i watched it i thought to my self i would'nt mind having a go at this game ! especially for $ xxunk . so anyway i would recommend you watch it and make up your own mind .
# y: CategoryList
# neg,neg,neg,neg,neg
# Path: /root/.fastai/data/imdb;
#
# Valid: LabelList (25000 items)
# x: TextList
# xxbos xxmaj really , xxup really ... xxmaj what pleases audience ( american one ! ) in this so called show is totally beyond me . xxmaj what can we learn from these series :
#
#   1 . xxmaj each casino there is spending about 2 - 3 billion bucks every year to rent a satellite and enormous quantity of hi tech high resolution cameras for their security team . xxmaj let xxup fbi bites the dust of them .
#
#   2 . xxmaj every security employee must have voluptuous breasts , of course natural ones . xxmaj the tits must be shown all the time otherwise they will lose their job .
#
#   3 . xxmaj if the employee happens to be a male , he needs to get breasts implanted , then go to step 2 .
#
#   4 . xxmaj only in xxmaj hollywood one can blatantly rip off other show 's ideas then implement them as their own and call all this crap " original " and " art " .
#
#   5 . xxmaj every security with tits bigger than xxup xxunk is considered immortal and can not die .
#
#   i really would like to have the opportunity to vote with minus values . -10 / 10 for this one !,xxbos xxmaj in short this movie was awful .
#
#   i understand it 's a xxmaj disney movie , which are generally shallow movies with mediocre plots and bad acting . xxup however , i must say this is the worst of all xxmaj disney movies , with bad acting , xxup lots xxup of xxup irritating xxup shrieking xxup teen xxunk god ) , and an extremely unrealistic plot . xxmaj even as a 12 year old there is no way i would have liked this movie . xxmaj the only way this movie could have been any worse is if they attempted to put it in theaters or tried to sell it in a local video store .
#
#   xxmaj do yourself a favor and change the channel before watching this , no matter how bored you are on a xxmaj sunday afternoon .,xxbos xxmaj poor xxmaj casper xxmaj van xxmaj dien , his career has slid a long way from xxmaj tarzan and xxmaj starship xxmaj troopers .
#
#   xxmaj in xxmaj meltdown he 's a policeman who just happens to be dating xxup tv reporter xxmaj stefanie xxmaj von xxmaj xxunk and her brother is a scientist who 's trying to deal with a speeding comment headed for xxmaj earth . xxmaj but in the runaway comet business , even a near miss causes some real problems as the xxmaj earth 's orbit goes out of kilter .
#
#   xxmaj from the survival of the xxmaj earth we go to the survival of xxmaj van xxmaj dien and his immediate family . xxmaj his daughter 's gangbanger boyfriend , xxmaj ryan mcdonell actually proves to be of some use especially when he suspects a guy he knows as a crooked cop might mean the xxmaj van xxmaj dien group a lot of harm .
#
#   xxmaj my only question here is , why did n't they have xxmaj bruce xxmaj willis , xxmaj billy xxmaj bob xxmaj thornton and the rest of that crew to deal with the nasty comet ?
#
#   xxmaj pass this one up folks .,xxbos xxmaj norris plays a xxmaj chicago cop who stumbles upon a devil 's apprentice ? who wants to , well , create xxmaj xxunk . xxmaj he eventually kills the creature by , get this , throwing a solid gold 24 inch spike , not very sharp , about twenty feet , hard enough to penetrate the chest . xxmaj unlikely ? xxmaj so is the rest of the movie . xxmaj much of it consists of xxup cn and his sidekick driving cars and talking nonsense . xxmaj the xxmaj israeli ( or xxmaj arab ) kid is there ostensibly to humanize xxup cn . xxup ok . xxmaj does n't work , makes no sense , and advances the plot , so - called , not one bit . xxmaj also , no cops ever every get invited out of the country to be interviewed by other cops . xxmaj it is ridiculous as a premise . xxmaj the whole thing is bad . xxmaj unfortunately , it 's not so bad as to be entertainingly bad or campy . xxmaj just plain bad . xxmaj but -- one can see how xxmaj norris was trying to find his way to the successful xxmaj walker : xxmaj texas xxmaj ranger series .,xxbos xxmaj for those of you who have never heard of the movie until now ( of which , i presume there are many lucky people who have n't ) , i 'll summarise it for you . xxmaj ryan xxmaj gosling plays the titular character of xxmaj leland , who also serves as the film 's narrator ( a la xxmaj kevin xxmaj spacey in xxmaj american xxmaj beauty , but without the intelligent observations on life ) . xxmaj leland goes to jail for stabbing a retarded kid to death , and the movie attempts to figure out why he did it . xxmaj he seems to be a nice boy ( if not mentally absent ) , and is portrayed by xxmaj gosling with a complete lack of violence , anger , or agenda ( and if you 're waiting for him to reveal his sinister side later in the movie , do n't waste your time-- it 's not that kind of movie ) . xxmaj once in juvenile prison , xxmaj leland goes to classes taught by xxmaj pearl xxmaj madison , ably portrayed by xxmaj don xxmaj cheadle ( who is incapable of anything but quality , even when in bad movies ) . xxmaj pearl attempts to unlock the mystery of xxmaj leland in an attempt to figure out how such a kid could do such a thing , and so he could write a book about it later ( along with being a juvenile prison teacher , xxmaj pearl is also an aspiring author ) .
#
#   xxmaj the relationship between xxmaj leland and xxmaj pearl is the driving narrative behind the film , as their talks unveil xxmaj leland 's past to the audience . xxmaj however , to call it the central focus would imply that this meandering film had one . xxmaj it does not . xxmaj the xxmaj united xxmaj states of xxmaj leland boasts an impressive cast , which seems to be to the detriment of the film . xxmaj it seems as though writer / director xxmaj matthew xxmaj ryan xxmaj hodge ( do n't worry that you have n't heard of him , he 's never done anything ) had to give xxup every character a personal story arc and personality flaw in order to get the actors to play them . xxmaj most of these traits and stories are clichéd , and most go underdeveloped and unresolved .
#
#   i 'll try and break them down here : xxmaj martin xxmaj donovan and xxmaj ann xxmaj xxunk are the parents of the slain retarded boy ( i love how the movie kept calling the kid " retarded " , never " mentally disabled " . xxmaj that part made me laugh inside ) , they apparently have a cold relationship , because all suburban marriages in contemporary cinema must be cold . xxmaj their other two kids are xxmaj michelle xxmaj williams , who is apparently an aspiring actress about to attend college , and xxmaj jena xxmaj malone , who plays the same troubled teen - archetype she always plays , this time with a heroine addiction . xxmaj malone was also the girlfriend of xxmaj leland , which gives him his link to his victim . xxmaj williams ' boyfriend , who was orphaned and came to live with the family , and is a baseball player looking to go to the same college as his girlfriend , is played by xxmaj chris xxmaj klein . xxmaj he ends up doing more with his character than any of the other bit players , managing to steal the movie at times . xxmaj lena xxmaj olin is xxmaj leland 's mother , who seems to be perpetually sad for some reason . xxmaj kevin xxmaj spacey ( also the executive producer ) is xxmaj leland 's cold and absentee father , who is a famed novelist . xxmaj eventually , xxmaj sherilyn xxmaj fenn will show up to put a wrinkle in xxmaj leland 's story-- if you even care at that point . xxmaj oh yeah , and there 's a drug - dealing ex - boyfriend , a couple of fellow xxunk , and a co - worker of xxmaj pearl 's with whom he has an affair on his long distance girlfriend with ( played by xxmaj kerry xxmaj washington ) .
#
#   xxmaj sorry if all that synopsis and character breakdown took so long . xxmaj if it seemed meaningless and boring , then you 've just experienced a bit of what i did during the 108 minutes i spent watching the movie . xxmaj but the unruly supporting cast of over - wrought clichés is the least of this film 's crimes . xxmaj the biggest one is that the whole exercise is entirely pointless . xxmaj we are n't given a fascinating look into a troubled mind , we are n't given an effective explanation , we are n't given much of anything . xxmaj given that it sucked so much , i 'm gon na go ahead and spoil the ending for you so that you never have to see it : xxmaj leland stabbed the retard because all xxmaj leland could see in the world was sadness , and wanted to spare xxmaj corky ( or whatever the victim 's name was ) the sadness in his eyes . xxmaj it 's like the worst emo band in the world made an album , and titled it " xxmaj the xxmaj world xxmaj is xxmaj sad , xxmaj so i xxmaj killed a xxmaj retard " . xxmaj oh , and xxmaj leland dies in the end , in a sequence so reliant of unbelievable coincidences that it would have ruined the movie , if the movie did n't already suck . xxmaj of course he dies in the end , because that made the movie so deep .
#
#   i 'm giving the movie 2 stars , because the actors themselves all did a pretty good job with the junk they were given . xxmaj the scenes with xxmaj cheadle and xxmaj gosling together were even interesting on some levels . xxmaj but , to paraphrase the film itself , you have to believe that movies are more than the sum of their parts , kiddo .
# y: CategoryList
# neg,neg,neg,neg,neg
# Path: /root/.fastai/data/imdb;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(60000, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(60000, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f11fc2b2d90>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/root/.fastai/data/imdb'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(60000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(60000, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(60000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(60000, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='94' class='' max='520' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.08% [94/520 00:16<01:15 1.9304]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(1, 2e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.293173</td>
#       <td>0.225584</td>
#       <td>0.908760</td>
#       <td>02:56</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('first')

# %%
learn.load('first');

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(1, slice(1e-2/(2.6**4),1e-2), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.243040</td>
#       <td>0.187096</td>
#       <td>0.928720</td>
#       <td>03:43</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('second')

# %%
learn.load('second');

# %%
learn.freeze_to(-3)
learn.fit_one_cycle(1, slice(5e-3/(2.6**4),5e-3), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.222775</td>
#       <td>0.161162</td>
#       <td>0.940280</td>
#       <td>04:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('third')

# %%
learn.load('third');

# %%
learn.unfreeze()
learn.fit_one_cycle(2, slice(1e-3/(2.6**4),1e-3), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.170739</td>
#       <td>0.154611</td>
#       <td>0.942640</td>
#       <td>06:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.133861</td>
#       <td>0.154124</td>
#       <td>0.943280</td>
#       <td>06:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
a,b,c =learn.predict("I really loved that movie, it was awesome!")

# %%
data_clas.classes[b]
# Out:
# 'pos'
